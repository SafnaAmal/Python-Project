# %% [markdown]
# #  Web Scrapping - Agriculture Energy  Policy Data

# %%
# Import LibraLibraries 
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
# Assigning URL 
url = "https://pmkusum.mnre.gov.in/landing.html"
page=requests.get(url)
soup=BeautifulSoup(page.text,'html')

# %%
# Calling all web page from website data
print(soup)
# Out:
# <html><body><p>ï»¿<!DOCTYPE html>
#
# </p>
# <title>PM KUSUM</title>
# <!-- for-mobile-apps -->
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script type="application/x-javascript">
# 		addEventListener("load", function () {
# 			setTimeout(hideURLbar, 0);
# 		}, false);
#
# 		function hideURLbar() {
# 			window.scrollTo(0, 1);
# 		}
# 	</script>
# <!-- //for-mobile-apps -->
# <link href="css/bootstrap.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="css/smartadmin-production-plugins.min.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="css/smartadmin-production.min.css" media="screen" rel="stylesheet" type="text/css"/>
# <!-- <link rel="stylesheet" type="text/css" media="screen" href="css/smartadmin-skins.min.css"> -->
# <link href="css/style.css" media="all" rel="stylesheet" type="text/css"/>
# <!-- font-awesome icons -->
# ...

# %%
# finding Table Content 
soup.find_all('table')[]
# Out:
# <table id="cmpaTabledummy">
# <caption>Component A</caption>
# <thead>
# <tr>
# <th>State</th>
# <th>Total Sanctioned <br/> Solar Capacity (MW)</th>
# <th>Total Installed <br/> Solar Capacity (MW)</th>
# <!-- <th></th>Total Sanctioned individual Pump Solar (IPS)</th>
# 										<th></th>Total Installed individual Pump Solar (IPS)</th>
# 										<th></th>Total Sanctioned Feeder Level solar(FLS)</th>
# 										<th></th>Total Installed Feeder Level solar(FLS)</th> -->
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Andhra Pradesh</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Arunachal Pradesh</td>
# <td>2</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Assam</td>
# <td>10</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Bihar</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Chhattisgarh</td>
# <td>30</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Delhi</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Goa</td>
# <td>150</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Gujarat</td>
# <td>500</td>
# <td>0</td>
# ...

# %%
print(table)
# Out:
# <table id="cmpbTabledummy">
# <caption>Component B</caption>
# <thead>
# <tr>
# <th>State</th>
# <th>Total Sanctioned Standalone <br/>Pumps Installed (Nos)</th>
# <th>Total Installed Standalone <br/>Pumps (Nos)</th>
# <!-- <th>Total Solar Capacity (MW)</th> -->
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Andhra Pradesh</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Arunachal Pradesh</td>
# <td>400</td>
# <td>199</td>
# </tr>
# <tr>
# <td>Assam</td>
# <td>4000</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Bihar</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Chhattisgarh</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Delhi</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Goa</td>
# <td>200</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Gujarat</td>
# <td>8082</td>
# <td>2459</td>
# </tr>
# <tr>
# <td>Haryana</td>
# <td>252655</td>
# <td>62103</td>
# </tr>
# <tr>
# <td>Himachal Pradesh</td>
# <td>1580</td>
# <td>501</td>
# </tr>
# <tr>
# <td>Jammu &amp; Kashmir</td>
# <td>5000</td>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th>State</th>,
#  <th>Total Sanctioned Standalone <br/>Pumps Installed (Nos)</th>,
#  <th>Total Installed Standalone <br/>Pumps (Nos)</th>]

# %%
# Taking cleaned and ordered Column name from scraped data
world_table_titles = [title.text.strip() for title in world_titles]

print(world_table_titles)
# Out:
# ['State', 'Total Sanctioned Standalone Pumps Installed (Nos)', 'Total Installed Standalone Pumps (Nos)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [State, Total Sanctioned Standalone Pumps Installed (Nos), Total Installed Standalone Pumps (Nos)]
# Index: []

# %%
# finding Column Value (row value) 
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                 State Total Sanctioned Standalone Pumps Installed (Nos)  \
# 0      Andhra Pradesh                                                 0
# 1   Arunachal Pradesh                                               400
# 2               Assam                                              4000
# 3               Bihar                                                 0
# 4        Chhattisgarh                                                 0
# 5               Delhi                                                 0
# 6                 Goa                                               200
# 7             Gujarat                                              8082
# 8             Haryana                                            252655
# 9    Himachal Pradesh                                              1580
# 10    Jammu & Kashmir                                              5000
# 11          Jharkhand                                             36717
# ...

# %%
# saving scrapped data in CSV Format
df.to_csv("C:/Users/HP/OneDrive/Agriculture_Energy_State_India.csv",index = False)
